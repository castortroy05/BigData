# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(color_codes=True)

# %matplotlib inline

# %%
df = pd.read_csv("cardata.csv")
print(df.shape)
# Out:
# (11914, 12)

# %%
df.head(5)
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#         Driven Mode  Number of Doors  highway MPG  city mpg  Popularity  Price
# 0  rear wheel drive              2.0           26        19        3916  46135
# 1  rear wheel drive              2.0           28        19        3916  40650
# 2  rear wheel drive              2.0           28        20        3916  36350
# 3  rear wheel drive              2.0           28        18        3916  29450
# 4  rear wheel drive              2.0           28        18        3916  34500

# %%
print(df.dtypes)
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven Mode           object
# Number of Doors      float64
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# Price                  int64
# dtype: object

# %%
duplicate_rows_df = df[df.duplicated()]
print(duplicate_rows_df)
# Out:
#          Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 14        BMW  1 Series  2013      230.0               6.0            MANUAL
# 18       Audi       100  1992      172.0               6.0            MANUAL
# 20       Audi       100  1992      172.0               6.0            MANUAL
# 24       Audi       100  1993      172.0               6.0            MANUAL
# 25       Audi       100  1993      172.0               6.0            MANUAL
# ...       ...       ...   ...        ...               ...               ...
# 11481  Suzuki      X-90  1998       95.0               4.0            MANUAL
# 11603   Volvo      XC60  2017      302.0               4.0         AUTOMATIC
# 11604   Volvo      XC60  2017      240.0               4.0         AUTOMATIC
# 11708  Suzuki       XL7  2008      252.0               6.0         AUTOMATIC
# 11717  Suzuki       XL7  2008      252.0               6.0         AUTOMATIC
#
#              Driven Mode  Number of Doors  highway MPG  city mpg  Popularity  \
# 14      rear wheel drive              2.0           28        19        3916
# 18     front wheel drive              4.0           24        17        3105
# 20     front wheel drive              4.0           24        17        3105
# 24     front wheel drive              4.0           24        17        3105
# 25     front wheel drive              4.0           24        17        3105
# ...                  ...              ...          ...       ...         ...
# 11481   four wheel drive              2.0           26        22         481
# 11603    all wheel drive              4.0           29        20         870
# 11604  front wheel drive              4.0           30        23         870
# 11708    all wheel drive              4.0           22        15         481
# 11717  front wheel drive              4.0           22        16         481
#
#        Price
# 14     31500
# 18      2000
# 20      2000
# 24      2000
# 25      2000
# ...      ...
# 11481   2000
# 11603  46350
# 11604  40950
# 11708  29149
# 11717  27499
#
# [886 rows x 12 columns]

# %%
df = df.drop_duplicates()
df.count()
# Out:
# Make                 11028
# Model                11028
# Year                 11028
# Engine HP            10959
# Engine Cylinders     10998
# Transmission Type    11028
# Driven Mode          11028
# Number of Doors      11022
# highway MPG          11028
# city mpg             11028
# Popularity           11028
# Price                11028
# dtype: int64

# %%
df = df.dropna()
print(df.count())
print(df.shape)
# Out:
# Make                 10929
# Model                10929
# Year                 10929
# Engine HP            10929
# Engine Cylinders     10929
# Transmission Type    10929
# Driven Mode          10929
# Number of Doors      10929
# highway MPG          10929
# city mpg             10929
# Popularity           10929
# Price                10929
# dtype: int64
# (10929, 12)

# %%
print(df.describe())
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  10929.000000  10929.000000      10929.000000     10929.000000
# mean    2010.768780    253.367188          5.679477         3.449172
# std        7.144636    109.969181          1.765286         0.875798
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    172.000000          4.000000         2.000000
# 50%     2015.000000    240.000000          6.000000         4.000000
# 75%     2016.000000    303.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity         Price
# count  10929.000000  10929.000000  10929.000000  1.092900e+04
# mean      26.336719     19.346875   1557.566932  4.213557e+04
# std        7.489187      6.625464   1448.307334  6.205717e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.169000e+04
# 50%       25.000000     18.000000   1385.000000  3.062000e+04
# 75%       30.000000     22.000000   2009.000000  4.310000e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
plt.hist(df['Engine HP'], bins = 20)
plt.title("Histogram of Engine HP")
plt.ylabel('Number of Engine HP')
plt.xlabel('Value of Engine HP')
# Out:
# Text(0.5, 0, 'Value of Engine HP')

# %%
plt.figure(figsize = (20, 10))
corl = df.corr()
sns.heatmap(corl, cmap = "BrBG", annot = True)
print(corl)
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.327957         -0.037097         0.245177
# Engine HP         0.327957   1.000000          0.788036        -0.136082
# Engine Cylinders -0.037097   0.788036          1.000000        -0.153036
# Number of Doors   0.245177  -0.136082         -0.153036         1.000000
# highway MPG       0.272054  -0.421254         -0.612161         0.120556
# city mpg          0.224110  -0.473772         -0.632701         0.140437
# Popularity        0.085127   0.040507          0.039295        -0.060403
# Price             0.203604   0.660307          0.555170        -0.148377
#
#                   highway MPG  city mpg  Popularity     Price
# Year                 0.272054  0.224110    0.085127  0.203604
# Engine HP           -0.421254 -0.473772    0.040507  0.660307
# Engine Cylinders    -0.612161 -0.632701    0.039295  0.555170
# Number of Doors      0.120556  0.140437   -0.060403 -0.148377
# highway MPG          1.000000  0.841519   -0.022937 -0.209936
# city mpg             0.841519  1.000000   -0.005554 -0.234567
# Popularity          -0.022937 -0.005554    1.000000 -0.048684
# Price               -0.209936 -0.234567   -0.048684  1.000000

# %%
fig, ax = plt.subplots(figsize = (10, 6))
ax.scatter(df['Engine HP'], df['Price'])
ax.set_xlabel('Engine HP')
ax.set_ylabel('Price')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 6))
ax.scatter(df['city mpg'], df['highway MPG'])
ax.set_xlabel('city mpg')
ax.set_ylabel('highway mpg')
plt.show()

# %% [markdown]
# # Exercise 2

# %%
df2 = pd.read_csv("diabetes.csv")
print(df2.shape)
df2.head(0)
# Out:
# (767, 9)
# Empty DataFrame
# Columns: [6, 148, 72, 35, 0, 33.6, 0.627, 50, 1]
# Index: []

# %%
print(df2.dtypes)
# Out:
# 6          int64
# 148        int64
# 72         int64
# 35         int64
# 0          int64
# 33.6     float64
# 0.627    float64
# 50         int64
# 1          int64
# dtype: object

# %%
df2.head(10)
# Out:
#     6  148  72  35    0  33.6  0.627  50  1
# 0   1   85  66  29    0  26.6  0.351  31  0
# 1   8  183  64   0    0  23.3  0.672  32  1
# 2   1   89  66  23   94  28.1  0.167  21  0
# 3   0  137  40  35  168  43.1  2.288  33  1
# 4   5  116  74   0    0  25.6  0.201  30  0
# 5   3   78  50  32   88  31.0  0.248  26  1
# 6  10  115   0   0    0  35.3  0.134  29  0
# 7   2  197  70  45  543  30.5  0.158  53  1
# 8   8  125  96   0    0   0.0  0.232  54  1
# 9   4  110  92   0    0  37.6  0.191  30  0

# %%
duplicate_rows_df2 = df2[df2.duplicated()]
print(print("number of duplicate rows: ", duplicate_rows_df2.shape))
# Out:
# number of duplicate rows:  (0, 9)
# None

# %%
print(df2.describe())
# Out:
#                 6         148          72          35           0        33.6  \
# count  767.000000  767.000000  767.000000  767.000000  767.000000  767.000000
# mean     3.842243  120.859192   69.101695   20.517601   79.903520   31.990482
# std      3.370877   31.978468   19.368155   15.954059  115.283105    7.889091
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   32.000000   32.000000
# 75%      6.000000  140.000000   80.000000   32.000000  127.500000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#             0.627          50           1
# count  767.000000  767.000000  767.000000
# mean     0.471674   33.219035    0.348110
# std      0.331497   11.752296    0.476682
# min      0.078000   21.000000    0.000000
# 25%      0.243500   24.000000    0.000000
# 50%      0.371000   29.000000    0.000000
# 75%      0.625000   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
print(df2.isnull().sum())
# Out:
# 6        0
# 148      0
# 72       0
# 35       0
# 0        0
# 33.6     0
# 0.627    0
# 50       0
# 1        0
# dtype: int64

# %%
print((df2[[1,2,3,4,5]] == 0).sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_16032/424646924.py in <module>
# ----> 1 print((df2[[1,2,3,4,5]] == 0).sum())
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Int64Index([1, 2, 3, 4, 5], dtype='int64')] are in the [columns]"

# %%
df2[[1,2,3,4,5]] = df2[[1,2,3,4,5]].replace(0, np.NaN)

# %%
df2.fillna(df2.mean(), inplace=True)
print(df2.isnull().sum())
print(df2.head(10))
# Out:
# 6        0
# 148      0
# 72       0
# 35       0
# 0        0
# 33.6     0
# 0.627    0
# 50       0
# 1        0
# dtype: int64
#     6  148  72  35    0  33.6  0.627  50  1
# 0   1   85  66  29    0  26.6  0.351  31  0
# 1   8  183  64   0    0  23.3  0.672  32  1
# 2   1   89  66  23   94  28.1  0.167  21  0
# 3   0  137  40  35  168  43.1  2.288  33  1
# 4   5  116  74   0    0  25.6  0.201  30  0
# 5   3   78  50  32   88  31.0  0.248  26  1
# 6  10  115   0   0    0  35.3  0.134  29  0
# 7   2  197  70  45  543  30.5  0.158  53  1
# 8   8  125  96   0    0   0.0  0.232  54  1
# 9   4  110  92   0    0  37.6  0.191  30  0

# %%
plt.figure(0)
plt.hist(df2[2], bins=20)
plt.title("Histogram of Plasma Glucose concentration")
plt.ylabel('Number of Plasma Glucose concentration')
plt.xlabel('Value of Plasma Glucose concentration');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3039/2370667418.py in <module>
#       1 plt.figure(0)
# ----> 2 plt.hist(df2[2], bins=20)
#       3 plt.title("Histogram of Plasma Glucose concentration")
#       4 plt.ylabel('Number of Plasma Glucose concentration')
#       5 plt.xlabel('Value of Plasma Glucose concentration');
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 2

# %%
plt.figure(1)
plt.hist(df2[5], bins=20)
plt.title("Histogram of Body mass index")
plt.ylabel('Number of Body mass index')
plt.xlabel('Value of Body mass index');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3039/4253215476.py in <module>
#       1 plt.figure(1)
# ----> 2 plt.hist(df2[5], bins=20)
#       3 plt.title("Histogram of Body mass index")
#       4 plt.ylabel('Number of Body mass index')
#       5 plt.xlabel('Value of Body mass index');
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 5

# %%
plt.figure(figsize=(20,10))
corl= df2.corr()
sns.heatmap(corl,cmap="BrBG",annot=True)
print(corl)
# Out:
#               6       148        72        35         0      33.6     0.627  \
# 6      1.000000  0.128846  0.141197 -0.082495 -0.072999  0.017518 -0.033927
# 148    0.128846  1.000000  0.152498  0.056381  0.332383  0.220955  0.136903
# 72     0.141197  0.152498  1.000000  0.207308  0.089098  0.281777  0.041180
# 35    -0.082495  0.056381  0.207308  1.000000  0.437974  0.392553  0.183498
# 0     -0.072999  0.332383  0.089098  0.437974  1.000000  0.198111  0.185579
# 33.6   0.017518  0.220955  0.281777  0.392553  0.198111  1.000000  0.140546
# 0.627 -0.033927  0.136903  0.041180  0.183498  0.185579  0.140546  1.000000
# 50     0.544018  0.262408  0.239571 -0.115873 -0.040942  0.035911  0.032738
# 1      0.221087  0.465856  0.064882  0.073265  0.131984  0.292695  0.173245
#
#              50         1
# 6      0.544018  0.221087
# 148    0.262408  0.465856
# 72     0.239571  0.064882
# 35    -0.115873  0.073265
# 0     -0.040942  0.131984
# 33.6   0.035911  0.292695
# 0.627  0.032738  0.173245
# 50     1.000000  0.236417
# 1      0.236417  1.000000

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df2[3], df2[5])
ax.set_xlabel('Triceps skinfold thickness ')
ax.set_ylabel('Body mass index')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3039/1662297987.py in <module>
#       1 fig, ax = plt.subplots(figsize=(10,6))
# ----> 2 ax.scatter(df2[3], df2[5])
#       3 ax.set_xlabel('Triceps skinfold thickness ')
#       4 ax.set_ylabel('Body mass index')
#       5 plt.show()
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/anaconda3/envs/bd/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 3
